# %% [markdown]
# <a href="https://colab.research.google.com/github/yyuukkee/DeepLearning/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyodbc
conn = pyodbc.connect("DSN=Cloudera Hive DSN; Host=3.147.69.27; Port=10000;", autocommit=True)
cursor = conn.cursor()
cursor.execute("select symbol,trade_date as dividend_date, dividend from default.dividends_data where symbol = 'IBM' and year(trade_date) = '1990'")
result = cursor.fetchall()
for r in result:
    print(r)
# Out:
# ('IBM', '1990-11-05', 0.30250000953674316)
# ('IBM', '1990-08-06', 0.30250000953674316)
# ('IBM', '1990-05-04', 0.30250000953674316)
# ('IBM', '1990-02-05', 0.30250000953674316)

# %%
conn = pyodbc.connect("DSN=Cloudera Hive DSN;Host=3.147.69.27;Port=10000;", autocommit=True)
cursor = conn.cursor()

assigned_year = '2002'

cursor.execute(f"""
    SELECT year, symbol, total_dividends
    FROM default.yearly_aggregates
    WHERE symbol = 'IBM' AND year = '{assigned_year}'
""")

result = cursor.fetchall()
for r in result:
    print(f"{r.year}, {r.symbol}, {round(r.total_dividends, 3)}")

"""

2002, IBM, 0.59

"""
# Out:
# 2002, IBM, 0.59
# '\n\n2009, IBM, 2.15\n\n'
